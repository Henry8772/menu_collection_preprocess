# %%
import cv2
import os
from PIL import Image
import numpy as np

# %%
def variance_of_laplacian(image):
    # compute the Laplacian of the image and then return the focus measure,
    # which is simply the variance of the Laplacian
    return cv2.Laplacian(image, cv2.CV_64F).var()

def check_image_clarity(image, threshold=100.0):
    gray = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    fm = variance_of_laplacian(gray)
    return fm > threshold

def process_images(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            path = os.path.join(directory, filename)
            try:
                img = Image.open(path)
                if check_image_clarity(img):
                    print(f"Filename: {filename}")
                    print(f"Format: {img.format}")
                    print(f"Mode: {img.mode}")
                    print(f"Size: {img.size}")
                    print(f"Resolution: {img.info.get('dpi')}")
                    print("Image is clear")
                    print("--------------------------------")
                else:
                    print(f"{filename} is not clear.")
                    print("--------------------------------")
            except IOError:
                print("Cannot open image file.")
            except Exception as e:
                print("Error occurred: ", e)

# %%
path = './test_image/test1.jpg'
img = Image.open(path)
if check_image_clarity(img):
    print(f"Format: {img.format}")
    print(f"Mode: {img.mode}")
    print(f"Size: {img.size}")
    print(f"Resolution: {img.info.get('dpi')}")
    print("Image is clear")
# Out:
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear

# %%
path = './test_image/test2.jpg'
img = Image.open(path)
if check_image_clarity(img):
    print(f"Format: {img.format}")
    print(f"Mode: {img.mode}")
    print(f"Size: {img.size}")
    print(f"Resolution: {img.info.get('dpi')}")
    print("Image is clear")
# Out:
# Format: JPEG
# Mode: RGB
# Size: (240, 180)
# Resolution: (72, 72)
# Image is clear

# %%
process_images(".\images")
# Out:
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (446, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (489, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (607, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 451)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Error occurred:  OpenCV(4.7.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0x73cf019b::Set<1,-1,-1>,struct cv::impl::A0x73cf019b::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_40.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_41.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_42.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_43.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_44.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_45.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_46.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_47.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_48.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_49.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_50.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_51.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_52.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_53.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_54.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_55.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_56.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_57.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_58.jpg
# Format: JPEG
# Mode: RGB
# Size: (481, 609)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_59.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (450, 799)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_60.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_61.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_62.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_63.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 439)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 395)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (502, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 504)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Cannot open image file.
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (331, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_40.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_41.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_42.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_43.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_44.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_45.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_46.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_47.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_49.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_50.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_51.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_52.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_53.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_54.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_55.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_56.jpg
# Format: JPEG
# Mode: RGB
# Size: (450, 800)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_57.jpg
# Format: JPEG
# Mode: RGB
# Size: (450, 800)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (431, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (490, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (502, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (631, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (572, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (324, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_40.jpg
# Format: JPEG
# Mode: RGB
# Size: (323, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (467, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 566)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (323, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (467, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (466, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (441, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (512, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (512, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (512, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# ...
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_93.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_94.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_95.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_96.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_97.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_98.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_99.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (518, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (523, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (524, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 325)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (526, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (524, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 664)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (459, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (443, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (506, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# bluefrog蓝蛙(长宁来福士店)_mix_photos_12.jpg is not clear.
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 394)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (527, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# bluefrog蓝蛙(长宁来福士店)_mix_photos_4.jpg is not clear.
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 394)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (527, 700)
# Resolution: None
# Image is clear
# --------------------------------

# %%
# Usage
process_images(".\images")
# Out:
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (446, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (489, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (607, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 451)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Error occurred:  OpenCV(4.7.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0x73cf019b::Set<1,-1,-1>,struct cv::impl::A0x73cf019b::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_40.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_41.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_42.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_43.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_44.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_45.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_46.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_47.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_48.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_49.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_50.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_51.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_52.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_53.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_54.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_55.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_56.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_57.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_58.jpg
# Format: JPEG
# Mode: RGB
# Size: (481, 609)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_59.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (450, 799)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_60.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_61.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_62.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_63.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 439)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 395)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (502, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 504)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Cannot open image file.
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(189弄购物中心店)_receipt_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (331, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(七宝万科广场店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_40.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_41.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_42.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_43.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 524)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_44.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_45.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_46.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_47.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_49.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_50.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_51.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_52.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_53.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_54.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_55.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_56.jpg
# Format: JPEG
# Mode: RGB
# Size: (450, 800)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_57.jpg
# Format: JPEG
# Mode: RGB
# Size: (450, 800)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (431, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (490, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (502, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(万象城店)_receipt_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (631, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (572, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (324, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_40.jpg
# Format: JPEG
# Mode: RGB
# Size: (323, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (467, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海南翔印象城店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 566)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (323, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (467, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (466, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(上海金鹰国际店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (441, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (512, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (512, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (512, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_37.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_38.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(仲盛世界商城店)_menu_photos_39.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# ...
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_93.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_94.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_95.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_96.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_97.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_98.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_menu_photos_99.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_29.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_30.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_31.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_32.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_33.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_34.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_35.jpg
# Format: JPEG
# Mode: RGB
# Size: (518, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_36.jpg
# Format: JPEG
# Mode: RGB
# Size: (523, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥南丰城店)_receipt_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_menu_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (524, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_12.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 325)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_19.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (526, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_20.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_21.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_22.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_23.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_24.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_25.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_26.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_27.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_28.jpg
# Format: JPEG
# Mode: RGB
# Size: (524, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 664)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(虹桥龙湖天街店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_4.jpg
# Format: JPEG
# Mode: RGB
# Size: (459, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (443, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_menu_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_receipt_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(西郊百联店)_receipt_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (506, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_1.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 525)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_10.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_11.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# bluefrog蓝蛙(长宁来福士店)_mix_photos_12.jpg is not clear.
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_13.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_14.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 394)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_15.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_16.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_17.jpg
# Format: JPEG
# Mode: RGB
# Size: (527, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_18.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_2.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_3.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# bluefrog蓝蛙(长宁来福士店)_mix_photos_4.jpg is not clear.
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_5.jpg
# Format: JPEG
# Mode: RGB
# Size: (394, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_6.jpg
# Format: JPEG
# Mode: RGB
# Size: (700, 394)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_7.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: None
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_8.jpg
# Format: JPEG
# Mode: RGB
# Size: (525, 700)
# Resolution: (72, 72)
# Image is clear
# --------------------------------
# Filename: bluefrog蓝蛙(长宁来福士店)_mix_photos_9.jpg
# Format: JPEG
# Mode: RGB
# Size: (527, 700)
# Resolution: None
# Image is clear
# --------------------------------
